# %%
# !echo "$(whoami)@$(hostname)"
# Out:
# sothea@DESKTOP-VQHEPDC

# %%
import tensorflow as tf
import numpy as np
import matplotlib
import cv2

print("TensorFlow version:", tf.__version__)
print("NumPy version:", np.__version__)
print("Matplotlib version:", matplotlib.__version__)
print("OpenCV version:", cv2.__version__)
# Out:
# TensorFlow version: 2.21.0
# NumPy version: 2.4.6
# Matplotlib version: 3.11.0
# OpenCV version: 5.0.0

# %%
tf.config.list_logical_devices()
# Out:
# [LogicalDevice(name='/device:CPU:0', device_type='CPU')]

# %%
# !nvidia-smi
# Out:
# Fri Jul 10 16:30:02 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 610.43.02              KMD Version: 610.62        CUDA UMD Version: 13.3     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3050 ...    On  |   00000000:01:00.0 Off |                  N/A |
# | N/A   45C    P8              6W /   30W |       0MiB /   6144MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import os
# 1. Suppress TensorFlow's native C++ logs (0 = all, 1 = no INFO, 2 = no WARNING, 3 = no ERROR)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
